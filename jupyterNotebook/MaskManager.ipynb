# %%
import mask_master
# Out:
# Products are ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9'], in future scraped from Firebase
# End-users  are ['u1', 'u2', 'u3', 'u4', 'u5', 'u6', 'u7', 'u8', 'u9', 'u10', 'u11', 'u12'], scaped in future versions from BigQuery
# Initially no autogenerated Feed optimization is allowed, thus F in all cells.
#    u1 u2 u3 u4 u5 u6 u7 u8
# p1  F  F  F  F  F  F  F  F
# p2  F  F  F  F  F  F  F  F
# p3  F  F  F  F  F  F  F  F
# p4  F  F  F  F  F  F  F  F
# p5  F  F  F  F  F  F  F  F
# p6  F  F  F  F  F  F  F  F
# Freeing the mask for some Add and Drop actions, and both explicitly for u7/p6
# alfa_beta(users, products,'u2','u4','p2','p4','A') # partial call to allow Adds
# alfa_beta(users, products,'u3','u6','p3','p5','D') # partial call to allow Drops
# alfa_beta(users, products,'u7','u7','p6','p6','G') # partial call to allow just u7 be feed optimized both with Adds and Drops
#    u1 u2 u3 u4 u5 u6 u7 u8
# p1  F  F  F  F  F  F  F  F
# p2  F  A  A  A  F  F  F  F
# ...
